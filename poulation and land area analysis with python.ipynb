# %%
# !pip uninstall
# Out:
#   File "<ipython-input-89-4129f5e4b6d8>", line 1
#     unimport jovian
#              ^
# SyntaxError: invalid syntax

# %%
import os

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
os.listdir('.\Documents\my vba codingexcel')
# Out:
# ['Coindcx data with coding 1.xlsm',
#  'Coindcx data with coding 2.xlsm',
#  'Coindcx data with coding.xlsx',
#  'Coindcx data.xlsx',
#  'wikipedia world population.xlsx',
#  'wikipedia.xlsx',
#  'world population.csv',
#  'world populations.csv',
#  'world populations.xlsx',
#  'world populations12.csv']

# %%
path='.\Documents\my vba codingexcel\world population.csv'
df=pd.read_csv('.\Documents\my vba codingexcel\world population.csv', encoding='ISO-8859-1')
df.to_csv(path,encoding='utf-8', index=False)

# %%
world_population=df

# %%
world_population
# Out:
#        # Country (or dependency) Population (2020) Yearly Change  Net Change  \
# 0      1                   China     1,439,323,776         0.39%   5,540,090
# 1      2                   India     1,380,004,385         0.99%  13,586,631
# 2      3           United States       331,002,651         0.59%   1,937,734
# 3      4               Indonesia       273,523,615         1.07%   2,898,047
# 4      5                Pakistan       220,892,340         2.00%   4,327,022
# ..   ...                     ...               ...           ...         ...
# 230  231              Montserrat             4,992         0.06%           3
# 231  232        Falkland Islands             3,480         3.05%         103
# 232  233                    Niue             1,626         0.68%          11
# 233  234                 Tokelau             1,357         1.27%          17
# 234  235                Holy See               801         0.25%           2
#
# ...

# %%
world=world_population.head(10)

# %%
world
# Out:
#     # Country (or dependency) Population (2020) Yearly Change  Net Change  \
# 0   1                   China     1,439,323,776         0.39%   5,540,090
# 1   2                   India     1,380,004,385         0.99%  13,586,631
# 2   3           United States       331,002,651         0.59%   1,937,734
# 3   4               Indonesia       273,523,615         1.07%   2,898,047
# 4   5                Pakistan       220,892,340         2.00%   4,327,022
# 5   6                  Brazil       212,559,417         0.72%   1,509,890
# 6   7                 Nigeria       206,139,589         2.58%   5,175,990
# 7   8              Bangladesh       164,689,383         1.01%   1,643,222
# 8   9                  Russia       145,934,462         0.04%      62,206
# 9  10                  Mexico       128,932,753         1.06%   1,357,224
#
#   Density (P/KmÃÂÃÂÃÂÃÂ²) Land Area (KmÃÂÃÂÃÂÃÂ²)  \
# 0                            153                      9,388,211
# ...

# %%
world.columns
# Out:
# Index(['#', 'Country (or dependency)', 'Population (2020)', 'Yearly Change',
#        'Net Change', 'Density (P/KmÃÂÃÂÃÂÃÂ²)',
#        'Land Area (KmÃÂÃÂÃÂÃÂ²)', 'Migrants (net)', 'Fert. Rate',
#        'Med. Age', 'Urban Pop %', 'World Share'],
#       dtype='object')

# %%
world['Country (or dependency)']
# Out:
# 0            China
# 1            India
# 2    United States
# 3        Indonesia
# 4         Pakistan
# 5           Brazil
# 6          Nigeria
# 7       Bangladesh
# 8           Russia
# 9           Mexico
# Name: Country (or dependency), dtype: object

# %%
selected_columns=['Country (or dependency)',
                  'Population (2020)'
]

# %%
population=[selected_columns].copy()

# %%
population
# Out:
# [['Country (or dependency)', 'Population (2020)']]

# %%
world_df = world[['Country (or dependency)','Population (2020)']];

# %%
world_df
# Out:
#   Country (or dependency) Population (2020)
# 0                   China     1,439,323,776
# 1                   India     1,380,004,385
# 2           United States       331,002,651
# 3               Indonesia       273,523,615
# 4                Pakistan       220,892,340
# 5                  Brazil       212,559,417
# 6                 Nigeria       206,139,589
# 7              Bangladesh       164,689,383
# 8                  Russia       145,934,462
# 9                  Mexico       128,932,753

# %%
world=world_df.rename({'Country (or dependency)':'Country','Population (2020)':'Population'},axis=1)

# %%
world
# Out:
#          Country     Population
# 0          China  1,439,323,776
# 1          India  1,380,004,385
# 2  United States    331,002,651
# 3      Indonesia    273,523,615
# 4       Pakistan    220,892,340
# 5         Brazil    212,559,417
# 6        Nigeria    206,139,589
# 7     Bangladesh    164,689,383
# 8         Russia    145,934,462
# 9         Mexico    128,932,753

# %%
world.describe()
# Out:
#               Country   Population
# count              10           10
# unique             10           10
# top     United States  273,523,615
# freq                1            1

# %%
type(world_df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(world.Population)
# Out:
# pandas.core.series.Series

# %%
a=world.Population

# %%
world['Population']=world['Population'].str.replace(",","").astype(float)

# %%
world
# Out:
#          Country    Population
# 0          China  1.439324e+09
# 1          India  1.380004e+09
# 2  United States  3.310027e+08
# 3      Indonesia  2.735236e+08
# 4       Pakistan  2.208923e+08
# 5         Brazil  2.125594e+08
# 6        Nigeria  2.061396e+08
# 7     Bangladesh  1.646894e+08
# 8         Russia  1.459345e+08
# 9         Mexico  1.289328e+08

# %%
plt.figure(figsize=(16,8))
plt.xticks(rotation=(75))
sns.barplot( x='Country', y ='Population',data= world);

# %%
plt.figure(figsize= (12,6))
plt.title('world Population')
plt.pie(world.Population,labels=world.Country);

# %%
world_population
# Out:
#        # Country (or dependency) Population (2020) Yearly Change  Net Change  \
# 0      1                   China     1,439,323,776         0.39%   5,540,090
# 1      2                   India     1,380,004,385         0.99%  13,586,631
# 2      3           United States       331,002,651         0.59%   1,937,734
# 3      4               Indonesia       273,523,615         1.07%   2,898,047
# 4      5                Pakistan       220,892,340         2.00%   4,327,022
# ..   ...                     ...               ...           ...         ...
# 230  231              Montserrat             4,992         0.06%           3
# 231  232        Falkland Islands             3,480         3.05%         103
# 232  233                    Niue             1,626         0.68%          11
# 233  234                 Tokelau             1,357         1.27%          17
# 234  235                Holy See               801         0.25%           2
#
# ...

# %%
world1=world_population.tail(225)

# %%
world1
# Out:
#        # Country (or dependency) Population (2020) Yearly Change Net Change  \
# 10    11                   Japan       126,476,461        -0.30%   -383,840
# 11    12                Ethiopia       114,963,588         2.57%  2,884,858
# 12    13             Philippines       109,581,078         1.35%  1,464,463
# 13    14                   Egypt       102,334,404         1.94%  1,946,331
# 14    15                 Vietnam        97,338,579         0.91%    876,473
# ..   ...                     ...               ...           ...        ...
# 230  231              Montserrat             4,992         0.06%          3
# 231  232        Falkland Islands             3,480         3.05%        103
# 232  233                    Niue             1,626         0.68%         11
# 233  234                 Tokelau             1,357         1.27%         17
# 234  235                Holy See               801         0.25%          2
#
# ...

# %%
world2=world1[['Country (or dependency)','Population (2020)']]

# %%
world2
# Out:
#     Country (or dependency) Population (2020)
# 10                    Japan       126,476,461
# 11                 Ethiopia       114,963,588
# 12              Philippines       109,581,078
# 13                    Egypt       102,334,404
# 14                  Vietnam        97,338,579
# ..                      ...               ...
# 230              Montserrat             4,992
# 231        Falkland Islands             3,480
# 232                    Niue             1,626
# 233                 Tokelau             1,357
# 234                Holy See               801
#
# [225 rows x 2 columns]

# %%
world3=world2.rename({'Country (or dependency)':'country','Population (2020)':'population'},axis=1)

# %%
world3
# Out:
#               country   population
# 10              Japan  126,476,461
# 11           Ethiopia  114,963,588
# 12        Philippines  109,581,078
# 13              Egypt  102,334,404
# 14            Vietnam   97,338,579
# ..                ...          ...
# 230        Montserrat        4,992
# 231  Falkland Islands        3,480
# 232              Niue        1,626
# 233           Tokelau        1,357
# 234          Holy See          801
#
# [225 rows x 2 columns]

# %%
world3['population']=world3['population'].str.replace(",","").astype(float)

# %%
world3
# Out:
#               country   population
# 10              Japan  126476461.0
# 11           Ethiopia  114963588.0
# 12        Philippines  109581078.0
# 13              Egypt  102334404.0
# 14            Vietnam   97338579.0
# ..                ...          ...
# 230        Montserrat       4992.0
# 231  Falkland Islands       3480.0
# 232              Niue       1626.0
# 233           Tokelau       1357.0
# 234          Holy See        801.0
#
# [225 rows x 2 columns]

# %%
world3.population.sum()
# Out:
# 3292230259.0

# %%
world
# Out:
#          Country    Population
# 0          China  1.439324e+09
# 1          India  1.380004e+09
# 2  United States  3.310027e+08
# 3      Indonesia  2.735236e+08
# 4       Pakistan  2.208923e+08
# 5         Brazil  2.125594e+08
# 6        Nigeria  2.061396e+08
# 7     Bangladesh  1.646894e+08
# 8         Russia  1.459345e+08
# 9         Mexico  1.289328e+08

# %%
world5=world.append({'Country':'Others','Population':'3292230259.0'},ignore_index=True)

# %%
world5
# Out:
#           Country    Population
# 0           China   1.43932e+09
# 1           India      1.38e+09
# 2   United States   3.31003e+08
# 3       Indonesia   2.73524e+08
# 4        Pakistan   2.20892e+08
# 5          Brazil   2.12559e+08
# 6         Nigeria    2.0614e+08
# 7      Bangladesh   1.64689e+08
# 8          Russia   1.45934e+08
# 9          Mexico   1.28933e+08
# 10         Others  3292230259.0

# %%
plt.figure(figsize= (20,10))
plt.title('world Population')
plt.pie(world5.Population,labels=world5.Country,autopct='%1.1f%%',shadow=True);

# %%
colors=['lightskyblue','red','yellow','green','blue','pink','brown','blue','black','yellow','orange']

# %%
plt.figure(figsize= (16,8))
plt.title('world Population')
plt.pie(world5.Population,labels=world5.Country,autopct='%1.1f%%',colors=colors);

# %%
world_population
# Out:
#        # Country (or dependency) Population (2020) Yearly Change  Net Change  \
# 0      1                   China     1,439,323,776         0.39%   5,540,090
# 1      2                   India     1,380,004,385         0.99%  13,586,631
# 2      3           United States       331,002,651         0.59%   1,937,734
# 3      4               Indonesia       273,523,615         1.07%   2,898,047
# 4      5                Pakistan       220,892,340         2.00%   4,327,022
# ..   ...                     ...               ...           ...         ...
# 230  231              Montserrat             4,992         0.06%           3
# 231  232        Falkland Islands             3,480         3.05%         103
# 232  233                    Niue             1,626         0.68%          11
# 233  234                 Tokelau             1,357         1.27%          17
# 234  235                Holy See               801         0.25%           2
#
# ...

# %%
world_land=world_population[['Country (or dependency)','Land Area (KmÃÂÃÂÃÂÃÂ²)']]

# %%
world_land
# Out:
#     Country (or dependency) Land Area (KmÃÂÃÂÃÂÃÂ²)
# 0                     China                      9,388,211
# 1                     India                      2,973,190
# 2             United States                      9,147,420
# 3                 Indonesia                      1,811,570
# 4                  Pakistan                        770,880
# ..                      ...                            ...
# 230              Montserrat                            100
# 231        Falkland Islands                         12,170
# 232                    Niue                            260
# 233                 Tokelau                             10
# 234                Holy See                              0
#
# [235 rows x 2 columns]

# %%
world_land1=world_land.rename({'Country (or dependency)':'country','Land Area (KmÃÂÃÂÃÂÃÂ²)':'land_area'},axis=1)

# %%
world_land1
# Out:
#               country  land_area
# 0               China  9,388,211
# 1               India  2,973,190
# 2       United States  9,147,420
# 3           Indonesia  1,811,570
# 4            Pakistan    770,880
# ..                ...        ...
# 230        Montserrat        100
# 231  Falkland Islands     12,170
# 232              Niue        260
# 233           Tokelau         10
# 234          Holy See          0
#
# [235 rows x 2 columns]

# %%
world_land1['land_area']=world_land1['land_area'].str.replace(",","").astype(float)

# %%
world_land3=world_land1.sort_values("land_area",ascending=False)

# %%
world_dff=world_land3.head(10)

# %%
world_dff
# Out:
#           country   land_area
# 8          Russia  16376870.0
# 0           China   9388211.0
# 2   United States   9147420.0
# 38         Canada   9093510.0
# 5          Brazil   8358140.0
# 54      Australia   7682300.0
# 1           India   2973190.0
# 31      Argentina   2736690.0
# 63     Kazakhstan   2699700.0
# 32        Algeria   2381740.0

# %%
world_dff1=world_dff.append({'country':'Others','land_area':'56989262'},ignore_index=True)

# %%
world_dff1
# Out:
#           country    land_area
# 0          Russia  1.63769e+07
# 1           China  9.38821e+06
# 2   United States  9.14742e+06
# 3          Canada  9.09351e+06
# 4          Brazil  8.35814e+06
# 5       Australia   7.6823e+06
# 6           India  2.97319e+06
# 7       Argentina  2.73669e+06
# 8      Kazakhstan   2.6997e+06
# 9         Algeria  2.38174e+06
# 10         Others     56989262

# %%
plt.figure(figsize=(12,6))
plt.title('World Land Area')
plt.pie(world_dff.land_area,labels=world_dff.country,autopct='%1.1f%%',colors=colors);

# %%
plt.figure(figsize= (16,8))
plt.title('world Population')
plt.pie(world5.Population,labels=world5.Country,autopct='%1.1f%%',colors=colors);

# %%
plt.figure(figsize=(12,8))
plt.title('world_land')
sns.barplot(x=world_dff.land_area , y=world_dff.country);
