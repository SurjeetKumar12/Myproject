# %%
# !pip install pandasql
# Out:
# Requirement already satisfied: pandasql in c:\users\jeet\anaconda3\new folder (2)\lib\site-packages (0.7.3)
# Requirement already satisfied: sqlalchemy in c:\users\jeet\anaconda3\new folder (2)\lib\site-packages (from pandasql) (1.3.20)
# Requirement already satisfied: pandas in c:\users\jeet\anaconda3\new folder (2)\lib\site-packages (from pandasql) (1.1.3)
# Requirement already satisfied: numpy in c:\users\jeet\anaconda3\new folder (2)\lib\site-packages (from pandasql) (1.19.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\jeet\anaconda3\new folder (2)\lib\site-packages (from pandas->pandasql) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\jeet\anaconda3\new folder (2)\lib\site-packages (from pandas->pandasql) (2020.1)
# Requirement already satisfied: six>=1.5 in c:\users\jeet\anaconda3\new folder (2)\lib\site-packages (from python-dateutil>=2.7.3->pandas->pandasql) (1.15.0)

# %%
import pandas as pd
import pandasql as ps

# %%
titanic_disaster_dataset =pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
print(titanic_disaster_dataset.shape,titanic_disaster_dataset[['PassengerId']].drop_duplicates().shape)
titanic_disaster_dataset.head()
# Out:
# (891, 12) (891, 1)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
ps.sqldf("""
SELECT
*
FROM titanic_disaster_dataset
""")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500  None        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250  None        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500  None        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000  None        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500  None        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500  None        Q
#
# [891 rows x 12 columns]

# %%
ps.sqldf("""
SELECT
df.*
FROM titanic_disaster_dataset AS df
""")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500  None        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250  None        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500  None        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000  None        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500  None        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500  None        Q
#
# [891 rows x 12 columns]

# %%
ps.sqldf("""
SELECT
df.*
FROM titanic_disaster_dataset AS df
LIMIT 5
""")
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500  None        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250  None        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500  None        S

# %%
ps.sqldf("""
SELECT
df.PassengerId,
df.Name
FROM titanic_disaster_dataset AS df
""")
# Out:
#      PassengerId                                               Name
# 0              1                            Braund, Mr. Owen Harris
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3                             Heikkinen, Miss. Laina
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5                           Allen, Mr. William Henry
# ..           ...                                                ...
# 886          887                              Montvila, Rev. Juozas
# 887          888                       Graham, Miss. Margaret Edith
# 888          889           Johnston, Miss. Catherine Helen "Carrie"
# 889          890                              Behr, Mr. Karl Howell
# 890          891                                Dooley, Mr. Patrick
#
# [891 rows x 2 columns]

# %%
ps.sqldf("""
SELECT
df.PassengerId AS Id_of_Passenger,
df.Name AS Name_of_Passenger
FROM titanic_disaster_dataset AS df
LIMIT 5

""")
# Out:
#    Id_of_Passenger                                  Name_of_Passenger
# 0                1                            Braund, Mr. Owen Harris
# 1                2  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                3                             Heikkinen, Miss. Laina
# 3                4       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                5                           Allen, Mr. William Henry

# %%
ps.sqldf("""
SELECT 
df.*
FROM titanic_disaster_dataset AS df
WHERE df.age<=5
LIMIT 5
""")
# Out:
#    PassengerId  Survived  Pclass                                      Name  \
# 0            8         0       3            Palsson, Master. Gosta Leonard
# 1           11         1       3           Sandstrom, Miss. Marguerite Rut
# 2           17         0       3                      Rice, Master. Eugene
# 3           44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# 4           59         1       2              West, Miss. Constance Mirium
#
#       Sex  Age  SibSp  Parch         Ticket     Fare Cabin Embarked
# 0    male  2.0      3      1         349909  21.0750  None        S
# 1  female  4.0      1      1        PP 9549  16.7000    G6        S
# 2    male  2.0      4      1         382652  29.1250  None        Q
# 3  female  3.0      1      2  SC/Paris 2123  41.5792  None        C
# 4  female  5.0      1      2     C.A. 34651  27.7500  None        S

# %%
ps.sqldf("""
SELECT 
df.*
FROM titanic_disaster_dataset AS df
WHERE df.age is NOT NULL
""")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 709          886         0       3
# 710          887         0       2
# 711          888         1       1
# 712          890         1       1
# 713          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 709               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 710                              Montvila, Rev. Juozas    male  27.0      0
# 711                       Graham, Miss. Margaret Edith  female  19.0      0
# 712                              Behr, Mr. Karl Howell    male  26.0      0
# 713                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500  None        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250  None        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500  None        S
# ..     ...               ...      ...   ...      ...
# 709      5            382652  29.1250  None        Q
# 710      0            211536  13.0000  None        S
# 711      0            112053  30.0000   B42        S
# 712      0            111369  30.0000  C148        C
# 713      0            370376   7.7500  None        Q
#
# [714 rows x 12 columns]

# %%
ps.sqldf("""
SELECT
df.*
FROM titanic_disaster_dataset AS df
WHERE df.age BETWEEN 5 AND 10
LIMIT 5
""")
# Out:
#    PassengerId  Survived  Pclass  \
# 0           25         0       3
# 1           51         0       3
# 2           59         1       2
# 3          148         0       3
# 4          166         1       3
#
#                                               Name     Sex  Age  SibSp  Parch  \
# 0                    Palsson, Miss. Torborg Danira  female  8.0      3      1
# 1                       Panula, Master. Juha Niilo    male  7.0      4      1
# 2                     West, Miss. Constance Mirium  female  5.0      1      2
# 3                 Ford, Miss. Robina Maggie "Ruby"  female  9.0      2      2
# 4  Goldsmith, Master. Frank John William "Frankie"    male  9.0      0      2
#
#        Ticket     Fare Cabin Embarked
# 0      349909  21.0750  None        S
# 1     3101295  39.6875  None        S
# 2  C.A. 34651  27.7500  None        S
# 3  W./C. 6608  34.3750  None        S
# 4      363291  20.5250  None        S

# %%
ps.sqldf("""
SELECT 
df.*
FROM titanic_disaster_dataset AS df
WHERE df.age<1
AND df.sex="female"
""")
# Out:
#    PassengerId  Survived  Pclass                           Name     Sex   Age  \
# 0          470         1       3  Baclini, Miss. Helene Barbara  female  0.75
# 1          645         1       3         Baclini, Miss. Eugenie  female  0.75
#
#    SibSp  Parch Ticket     Fare Cabin Embarked
# 0      2      1   2666  19.2583  None        C
# 1      2      1   2666  19.2583  None        C

# %%
ps.sqldf("""
SELECT 
df.*
FROM titanic_disaster_dataset AS df
WHERE(df.age<1 AND df.sex ="female")
OR (df.age>70 AND df.Pclass=1)
""")
# Out:
#    PassengerId  Survived  Pclass                                  Name  \
# 0           97         0       1             Goldschmidt, Mr. George B
# 1          470         1       3         Baclini, Miss. Helene Barbara
# 2          494         0       1               Artagaveytia, Mr. Ramon
# 3          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 4          645         1       3                Baclini, Miss. Eugenie
#
#       Sex    Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 0    male  71.00      0      0  PC 17754  34.6542    A5        C
# 1  female   0.75      2      1      2666  19.2583  None        C
# 2    male  71.00      0      0  PC 17609  49.5042  None        C
# 3    male  80.00      0      0     27042  30.0000   A23        S
# 4  female   0.75      2      1      2666  19.2583  None        C

# %%
ps.sqldf("""
SELECT 
df.*
FROM titanic_disaster_dataset AS df
WHERE df.Cabin IN ('A5','A6','A7')
""")
# Out:
#    PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 0           24         1       1  Sloper, Mr. William Thompson  male  28.0
# 1           97         0       1     Goldschmidt, Mr. George B  male  71.0
# 2          175         0       1       Smith, Mr. James Clinch  male  56.0
#
#    SibSp  Parch    Ticket     Fare Cabin Embarked
# 0      0      0    113788  35.5000    A6        S
# 1      0      0  PC 17754  34.6542    A5        C
# 2      0      0     17764  30.6958    A7        C

# %%
ps.sqldf("""
SELECT 
df.*
FROM titanic_disaster_dataset AS df
WHERE df.age IN (65,75,60)
""")
# Out:
#    PassengerId  Survived  Pclass  \
# 0           55         0       1
# 1          281         0       3
# 2          367         1       1
# 3          457         0       1
# 4          588         1       1
# 5          685         0       2
# 6          695         0       1
#
#                                                Name     Sex   Age  SibSp  \
# 0                    Ostby, Mr. Engelhart Cornelius    male  65.0      0
# 1                                  Duane, Mr. Frank    male  65.0      0
# 2  Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  female  60.0      1
# 3                         Millet, Mr. Francis Davis    male  65.0      0
# 4                  Frolicher-Stehli, Mr. Maxmillian    male  60.0      1
# 5                 Brown, Mr. Thomas William Solomon    male  60.0      1
# 6                                   Weir, Col. John    male  60.0      0
#
#    Parch  Ticket     Fare Cabin Embarked
# 0      1  113509  61.9792   B30        C
# 1      0  336439   7.7500  None        Q
# 2      0  110813  75.2500   D37        C
# 3      0   13509  26.5500   E38        S
# 4      1   13567  79.2000   B41        C
# 5      1   29750  39.0000  None        S
# 6      0  113800  26.5500  None        S

# %%
ps.sqldf("""
SELECT 
df.*
FROM titanic_disaster_dataset AS df
WHERE df.name LIKE "%MRS.%"
""")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              2         1       1
# 1              4         1       1
# 2              9         1       3
# 3             10         1       2
# 4             16         1       2
# ..           ...       ...     ...
# 120          872         1       1
# 121          875         1       2
# 122          880         1       1
# 123          881         1       2
# 124          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 1         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 2    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 3                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 4                     Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ..                                                 ...     ...   ...    ...
# 120   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 121              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 122      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 123       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 124               Rice, Mrs. William (Margaret Norton)  female  39.0      0
#
#      Parch     Ticket     Fare Cabin Embarked
# 0        0   PC 17599  71.2833   C85        C
# 1        0     113803  53.1000  C123        S
# 2        2     347742  11.1333  None        S
# 3        0     237736  30.0708  None        C
# 4        0     248706  16.0000  None        S
# ..     ...        ...      ...   ...      ...
# 120      1      11751  52.5542   D35        S
# 121      0  P/PP 3381  24.0000  None        C
# 122      1      11767  83.1583   C50        C
# 123      1     230433  26.0000  None        S
# 124      5     382652  29.1250  None        Q
#
# [125 rows x 12 columns]

# %%
ps.sqldf("""
SELECT 
df.age,
df.age*df.age AS age_sq,
df.age*1 AS age_plus_1
FROM titanic_disaster_dataset AS df
""")
# Out:
#       Age  age_sq  age_plus_1
# 0    22.0   484.0        22.0
# 1    38.0  1444.0        38.0
# 2    26.0   676.0        26.0
# 3    35.0  1225.0        35.0
# 4    35.0  1225.0        35.0
# ..    ...     ...         ...
# 886  27.0   729.0        27.0
# 887  19.0   361.0        19.0
# 888   NaN     NaN         NaN
# 889  26.0   676.0        26.0
# 890  32.0  1024.0        32.0
#
# [891 rows x 3 columns]

# %%
ps.sqldf("""
SELECT 
df.sex
FROM titanic_disaster_dataset AS df
""")
# Out:
#         Sex
# 0      male
# 1    female
# 2    female
# 3    female
# 4      male
# ..      ...
# 886    male
# 887  female
# 888  female
# 889    male
# 890    male
#
# [891 rows x 1 columns]

# %%
ps.sqldf("""
SELECT
df.sex,
df.Ticket,
df.sex || df.Ticket AS sex_plus_ticket
FROM titanic_disaster_dataset AS df
LIMIT 5
""")
# Out:
#       Sex            Ticket         sex_plus_ticket
# 0    male         A/5 21171           maleA/5 21171
# 1  female          PC 17599          femalePC 17599
# 2  female  STON/O2. 3101282  femaleSTON/O2. 3101282
# 3  female            113803            female113803
# 4    male            373450              male373450

# %%
titanic_disaster_dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
1
